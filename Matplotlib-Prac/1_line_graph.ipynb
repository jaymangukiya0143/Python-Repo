# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(x,y,'g*-', linewidth=1, markersize=10, alpha=0.8)

# %%
plt.plot(x,y,color="#FFE211", marker="D",linewidth=1, markersize=10)
