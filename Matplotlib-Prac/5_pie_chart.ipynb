# %%
import matplotlib.pyplot as plt

# %%
exp_values = [1400,600,300,410,250]
exp_labels = ['Home Rent','Food','Phone/Internet Bill','Car','Other Utilities']

# %%
plt.pie(exp_values, labels=exp_labels, radius=1.5, autopct='%0.2f%%', explode=[0,0.1,0,0.1,0], startangle=90)
plt.savefig("C:/Users/Lenovo/Desktop/pie_chart.pdf", bbox_inches="tight", pad_inches=2, transparent=True)
