# %%
# Pandas Time Series Part-1 (DateTimeIndex and Resample)

import pandas as pd

# %%
df = pd.read_csv('F:/Jay/Python/Code Basics Youtube/Pandas/15_aapl.csv', parse_dates=['Date'], index_col='Date')
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30', '2017-07-01', '2017-08-02'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df['2017-06']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_6236/2147835895.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-06']
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# ...

# %%
df['2017-06'].Close
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_6236/2595599473.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-06'].Close
# Date
# 2017-06-01    153.18
# 2017-06-02    155.45
# 2017-06-05    153.93
# 2017-06-06    154.45
# 2017-06-07    155.37
# 2017-06-08    154.99
# 2017-06-09    148.98
# 2017-06-12    145.42
# 2017-06-13    146.59
# 2017-06-14    145.16
# 2017-06-15    144.29
# 2017-06-16    142.27
# 2017-06-19    146.34
# 2017-06-20    145.01
# 2017-06-21    145.87
# 2017-06-22    145.63
# 2017-06-23    146.28
# 2017-06-26    145.82
# 2017-06-27    143.73
# 2017-06-28    145.83
# 2017-06-29    143.68
# 2017-06-30    144.02
# Name: Close, dtype: float64

# %%
df['2017-06'].Close.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_6236/2742124876.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-06'].Close.mean()
# 147.83136363636365

# %%
#df['2017-06-05']

# %%
df['2017-06-01':'2017-06-10']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657

# %%
# Resampling

# %matplotlib inline
df.Close.resample('W').mean().plot() # W = weekly frequency
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Open.resample('M').mean().plot(kind='bar') # M = monthly frequency
# Out:
# <AxesSubplot:xlabel='Date'>
